# %%
Red = 4
Blue = 6
Red_Taken = 1
Red_Left = Red - Red_Taken
Total_Left = Blue + Red_Left
Probability = Red_Left / Total_Left
print("Probability of (Red Left / Red Taken)",Probability * 100 , "%")
# Out:
# Probability of (Red Left / Red Taken) 33.33333333333333 %

# %%
Math = 20
Physics = 15
Both = 10
P = Both / (Math)
print("Probability of Physics",P * 100 , "%")
# Out:
# Probability of Physics 50.0 %

# %%
Male = 0.60
Female = 0.40
Male_IT = 0.50
Female_IT = 0.30
P = (Male_IT * Male) / (Male_IT * Male + Female_IT * Female)
print("Probability of Male",P * 100 , "%")
# Out:
# Probability of Male 71.42857142857143 %

# %%
P_Head = 0.5
P = P_Head
print("Probability of Head",P * 100 , "%")
# Out:
# Probability of Head 50.0 %

# %%
Red = 7
Blue = 5
Red -= 1
Total = Red + Blue
P = Blue / Total
print("Probability of Blue",P * 100 , "%")
# Out:
# Probability of Blue 45.45454545454545 %
