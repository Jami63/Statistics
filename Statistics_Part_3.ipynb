# %%
TO = 6
Even_Numbers = [2 , 4 , 6]
P = len(Even_Numbers) / TO
print("Probability of P = ", P * 100 , "%")
# Out:
# Probability of P =  50.0 %

# %%
H = [1]
T = 2
P = len(H) / T
print("Probability of getting Heads is: ", P * 100 , "%")
# Out:
# Probability of getting Heads is:  50.0 %

# %%
King = 4
Total_Cards = 52
King_Probability = King/Total_Cards
print("King Probability : ",King_Probability * 100 , "%")
# Out:
# King Probability :  7.6923076923076925 %

# %%
Red = 5
Blue = 3
Total = Red + Blue
Red_Probability = Red/Total
print("Red Probability : ",Red_Probability * 100 , "%")
# Out:
# Red Probability :  62.5 %

# %%
Girls = 8
Total = 20
Girls_Probability = Girls/Total
print("Girls Probability : ",Girls_Probability * 100 , "%")
# Out:
# Girls Probability :  40.0 %
